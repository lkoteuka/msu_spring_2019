# %% [markdown]
# # Алгоритмы интеллектуальной обработки больших объемов данных
# ## Домашнее задание №4 - Алгоритмы кластеризации

# %% [markdown]
# ###### <hr\>
# **Общая информация**
#
# **Срок сдачи:** 6 мая 2019, 06:00 <br\>
# **Штраф за опоздание:** -2 балла после 06:00 6 мая, -4 балла после 06:00 13 мая, -6 баллов после 06:00 20 мая -8 баллов  после 06:00 27 мая
#
#
# Используйте данный Ipython Notebook при оформлении домашнего задания.
# <hr\>

# %% [markdown]
# **Из чего состоит задание:**
#
# ###### Теоретические вопросы (2 балла)
#
# ###### Реализация алгоритма кластеризации (5 баллов)
#
# ###### Боевое применение (3 балла)

# %% [markdown]
# **Штрафные баллы:**
#
# 1. Невыполнение PEP8 -1 балл
# 2. Отсутствие фамилии в имени скрипта (скрипт должен называться по аналогии со stroykova_hw4.ipynb) -1 балл
# 3. Все строчки должны быть выполнены. Нужно, чтобы output команды можно было увидеть уже в git'е. В противном случае -1 балл
# 4. При оформлении ДЗ нужно пользоваться данным файлом в качестве шаблона. Не нужно удалять и видоизменять написанный код и текст. В противном случае -1 балл

# %%
import time
import pandas as pd
import pylab as pl
import numpy as np
import scipy.spatial as ss
import sklearn.cluster as sc
import sklearn.manifold as sm
import sklearn.datasets as ds
import sklearn.metrics as smt
from sklearn.mixture import GaussianMixture
from sklearn.cluster import AgglomerativeClustering

import matplotlib.pyplot as plt

from scipy.spatial import distance

# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,5)

# Plotting config
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Теоретическое введение

# %% [markdown]
# Основная задача кластерного анализа — разбиение исходного набора объектов на группы (кластеры) таким образом, чтобы объекты в группе были похожи друг на друга, а объекты из разных групп - отличались.
#
# В этой работе мы будем реализовывать агломеративную кластеризацию.

# %% [markdown]
# ## Агломеративная кластеризация

# %% [markdown]
# Иерархические алгоритмы кластеризации строят на выборке систему вложенных разбиений.  Наиболее часто испоьзуемые иерархические алгоритмы - агломеративные алгоритмы, которые строят ирархию по восходящей, то есть от момента, когда все элементы являются отдельными кластерами, до того момента, пока вся выборка не станет одним кластером.

# %% [markdown]
# Сам алгоритм описать можно примерно так:
#
# * начинаем с ситуации, когда каждый объект - отдельный кластер
# * на каждом шаге совмещаем два наиболее близких кластера
# * останавливаемся, когда получаем требуемое количество или единственный кластер

# %% [markdown]
# В данной работе Вам предлагается реализовать три варианта расстояний между кластерами, по которым Вы определяете пару для слияния:
# * Single linkage
# $$ d_{min}(C_i, C_j) = \min_{\mathbf{x} \in C_i, \mathbf{x}' \in C_j} \|\mathbf{x} -\mathbf{x}' \| $$
#
# * Complete linkage
# $$ d_{max}(C_i, C_j) = \max_{\mathbf{x} \in C_i, \mathbf{x}' \in C_j} \|\mathbf{x} -\mathbf{x}' \| $$
#
# * Average linkage
# $$ d_{avg}(C_i, C_j) = \frac{1}{n_i n_j}\sum_{\mathbf{x} \in C_i}\sum_{\mathbf{x}' \in C_j} \|\mathbf{x} -\mathbf{x}' \| $$
#
# Как считать расстояние $\|\mathbf{x} -\mathbf{x}' \|$ между объектами Вы должны выбрать сами.  Вы должны четко понимать, что выбор расстояния между объектами - самое важное в такого рода алгоритмах. Передавайте название расстояния в конструктор класса, а потом, в зависимости от названия, применяете ту или иную функцию для подсчета расстояния.

# %% [markdown]
# Для того, чтобы на втором этапе нам не пересчитывать заново расстояния между всеми парами кластеров, можно использовать Формулы Ланса-Вильямса, которые позволяют посчитать расстояние между кластерами после объединения, используя только расстояния между кластерами до объедения.  Таким образом, достаточно будет посчитать расстояния только между всеми одноэлементными кластерами (первый этап), а затем пересчитывать расстояния при их объединении через
# формулы Ланса-Вильямса.
#
# Общая  формула выглядит так:
# $$ d(C_i \cup C_j, C_k) = a_i \cdot d(C_i, C_k) + a_j \cdot d(C_j, C_k) + b \cdot d(C_i, C_j) + c \cdot |d(C_i, C_k) - d(C_j, C_k)|$$
#
# Можно показать, что все относительно разумные кластерные расстояния можно описать данной формулой.
#
# Для интересущих нас linkage:
#
# * single-linkage       $a_i = \frac{1}{2}, a_j =  \frac{1}{2}, b = 0, c =  - \frac{1}{2} $
#
# * complete-linkage     $a_i = \frac{1}{2}, a_j =  \frac{1}{2}, b = 0, c =   \frac{1}{2} $
#
# * average-linkage       $a_i = \frac{|C_i|}{|C_i \cup C_j|}, a_j =  \frac{|C_j|}{|C_i \cup C_j|}, b = 0, c = 0 $

# %% [markdown]
# # Теоретические вопросы (2 балла)
# В этой части Вам будут предложены теоретичские вопросы и задачи по теме. Вы, конечно, можете списать их у своего товарища или найти решение в интернете, но учтите, что они обязательно войдут в теоретический коллоквиум. Лучше разобраться в теме сейчас и успешно ответить на коллоквиуме, чем списать, не разобравшись в материале, и быть терзаемым совестью.
#
#
# Формулы надо оформлять в формате **LaTeX**.

# %% [markdown]
# Задача 1. Сходимость kmeans.
#
# Метод kmeans является частным случаем EM алгоритма и наиболее простым в обосновании сходимости. Докажите, что kmeans всегда сходится, и итераций не будет превышать $k^N$, где $k$ $-$ число кластеров, $N$ $-$ число объектов
#
# Подсказка: Вам стоит рассмотреть функционал, который минимизирует алгоритм, и подумать, как он изменяется на E шаге и на M шаге.

# %% [markdown]
# Изначально при кластеризации алгоритмом kmeans случайным образом выбираются центры кластеров, затем на каждом шаге считается расстояние от всех точек до центров и присваиваются к ближайшему. Центры кластеров пересчитываются по среднему значению элементов, принадлежащих кластеру и их центры смещаются. Если смещение центров кластеров становятся незначительными, то алгоритм останавливает работу (количество возможных разбиений конечного множества конечно, а на каждом шаге суммарное расстояние от объектов до центров кластеров уменьшается). Число итераций не будет превышать $k^N$, ведь это задача размещения с повторением, когда есть N элементов и k кластеров.

# %% [markdown]
# Задача 2. Сходимость EM.
#
# Разобравшись со сходимостью kmeans, можно догадаться и до ответа про EM алгоритм.
#
# При каком условии на правдоподобие системы EM алгоритм будет  сходиться?

# %% [markdown]
# EM-алгоритм основан на методе максимизации функции правдободобия, поэтому он будет сходится, если функция правдоподобия ограничена сверху.

# %% [markdown]
# Задача 3. Формулы Ланса-Вильямса.
#
# Формулы Ланса-Вильямса крайне удобны для быстрого пересчта расстояний в агломеративной кластеризации. Давайте докажем  формулы для single и complete linkage.
#
# Докажите, что:
#
# $d_{\min}(U \cup V, S) = \frac{1}{2} d_{\min}(U, S) + \frac{1}{2} d_{\min}(V, S)  - \frac{1}{2} | d_{\min}(U, S) - d_{\min}(V, S) |  $
#
#
# $d_{\max}(U \cup V, S) = \frac{1}{2} d_{\max}(U, S) + \frac{1}{2} d_{\max}(V, S)  + \frac{1}{2} | d_{\max}(U, S) - d_{\max}(V, S) |  $

# %% [markdown]
# $Доказательство:$
#
# $d_{\min}(U \cup V, S) = \min(d_{\min}(U, S),\ d_{\min}(V, S)) = \frac{1}{2} d_{\min}(U, S) + \frac{1}{2} d_{\min}(V, S)  - \frac{1}{2} | d_{\min}(U, S) - d_{\min}(V, S) |  $
#
# $d_{\max}(U \cup V, S) = \max(d_{\max}(U, S),\ d_{\max}(V, S)) = \frac{1}{2} d_{\max}(U, S) + \frac{1}{2} d_{\max}(V, S)  + \frac{1}{2} | d_{\max}(U, S) - d_{\max}(V, S) |  $

# %% [markdown]
# # Реализация алгоритма кластеризации  (5 баллов)

# %% [markdown]
# Алгоритм кластеризации должен удовлетворять следующему интерфейсу. Конструктор принимает набор параметров, необходимых для работы алгоритма кластеризации. Метод `fit` подсчитывает параметры модели и возвращает `self`. Метод `predict` возвращает вектор с индексами кластеров для поданных в него объектов `x`.

# %%
from sklearn.base import BaseEstimator, ClusterMixin
from sklearn.metrics import pairwise_distances_chunked as p_d_c
from scipy.spatial import distance
from scipy.cluster import hierarchy

import math

def dist(a, b):
    if self.metric == 'euclidean':
        diff = a - b
        return np.vdot(diff, diff) ** 0.5
    elif self.metric == 'manhattan':
        return np.sum(np.absolute(a - b))
    return None
        
class Clustering(BaseEstimator, ClusterMixin):
    """
    Implement clustering algorithm according 
    """
        
    def __init__(self, metric='euclidean', n_clusters=2, linkage='average', **kwargs):
        """
        metric - string with name of metric, for example, euclidean
        Please add necessary algoritm parameters to class constructor.
        """
        self.Z = []
        self.metric = metric
        self.n_clusters = n_clusters
        self.linkage = linkage
        if linkage == 'single':
            self.a1 = 0.5
            self.a2 = 0.5
            self.c = -0.5
        if linkage == 'complete':
            self.a1 = 0.5
            self.a2 = 0.5
            self.c = 0.5
        if linkage == 'average':
            self.c = 0
        
    def fit_predict(self, X):
        """
        Use data matrix x to compute model parameters and predict clusters
        """
        # вычислим матрицу попарных расстояний
        base_table = np.array(distance.cdist(X, X, metric=self.metric))
        
        # заменим нули на диагонали максимальным значением
        max_dist = base_table[np.unravel_index(np.argmax(base_table, axis=None), base_table.shape)]
        np.fill_diagonal(base_table, max_dist)
        
        # для отрисовки
        self.Z = hierarchy.linkage(X, self.linkage)
        
        # создадим словарь для хранения кластеров {номер_кластера : [список_элементов]}
        clusters = dict()
        for i in range(len(X)):
            clusters[i] = [i]
        
        while len(clusters.keys()) != self.n_clusters:
            #print(base_table)
            # найдём индексы i, j минимального элемента матрицы, они совпадают с классами в clusters
            a, b = np.unravel_index(np.argmin(base_table, axis=None), base_table.shape)
            
            
            # вычислим новые расстояния до изменившегося кластера
            for i in list(clusters.keys()):
                if self.linkage == 'average':
                    new_size = len(clusters[a]) + len(clusters[b])
                    self.a1 = len(clusters[a]) / new_size
                    self.a2 = len(clusters[b]) / new_size
                if i != a and i != b:
                    base_table[a][i] = (self.a1 * base_table[a][i]
                                       + self.a2 * base_table[b][i]
                                        + self.c * (base_table[a][i] - base_table[b][i]))
                    base_table[i][a] = base_table[a][i]
                # расстояние до первого элемента кластера храним, остальные ставим в максимальное значение
                for j in clusters[a] + clusters[b]:
                    if j != a:
                        base_table[i][j] = max_dist
                        base_table[j][i] = max_dist
            
            # ставим расстояние между элементами кластера в маскимальное значение
            for i in clusters[a]:
                for j in clusters[b]:
                    base_table[i][j] = max_dist
                    base_table[j][i] = max_dist
            
            # объединяем кластеры и удаляем добавляемый
            clusters[a] = clusters[a] + clusters[b]
            del clusters[b]
            #print(clusters)
            
        self.Z=np.array(self.Z, dtype='float64')
        #self.Z =np.array(distance.cdist(X, X, metric=self.metric))
        class_number = 0
        pred = np.ndarray(shape=(len(X),), dtype='int')
        for i in clusters.keys():
            for j in clusters[i]:
                pred[j] = class_number
            class_number += 1
        
        return pred
    
    def plot_dendrogram(self):
        """
        Try to visualize our data
        """
        plt.figure(figsize=(20, 10))
        hierarchy.dendrogram(self.Z)

# %%
clf = Clustering(metric='euclidean', n_clusters=2)
clf.fit_predict([[1],
               [4],
                [11],
                [9]])
# Out:
# array([0, 0, 1, 1])

# %% [markdown]
# Сначала проверим реализованный алгоритм кластеризации на классическом наборе данных [Iris](http://www.wikiwand.com/en/Iris_flower_data_set). Загрузим данные (они включены в библиотеку sklearn) и посмотрим на то, как они выглядят в двух проекциях (для простоты используем 2 класса из 3).

# %%
iris = ds.load_iris()
x_iris = iris.data[:100]
y_iris = iris.target[:100]

pl.figure(figsize=(10, 5))

pl.subplot(1, 2, 1)
pl.scatter(x_iris[:, 0], x_iris[:, 1], c=y_iris, cmap=pl.cm.PuOr, lw=0, s=30)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')

pl.subplot(1, 2, 2)
pl.scatter(x_iris[:, 2], x_iris[:, 3], c=y_iris, cmap=pl.cm.PuOr, lw=0, s=30)
plt.xlabel('Petal length')
plt.ylabel('Petal width')
pl.show()

# %% [markdown]
# Видно, что классы разделяются, поэтому можно надеяться, что наш алгоритм "найдет" кластеры, соответствующие исходным классам. Результат работы реализованного алгоритма кластеризации предлагается сравнить с эталонной кластеризацией. Для этого предлагается изучить метрику ([adjusted rand score](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.adjusted_rand_score.html)). В случае если значение этой метрики отличается от 1, предлагается поработать над улучшением реализации своего алгоритма.

# %%
# Давайте проверим, как справляются sklearn реализации
sklearn_aggl = AgglomerativeClustering(n_clusters=2)
aggl_t0 = time.time()
aggl_pred = sklearn_aggl.fit_predict(x_iris)
aggl_diff = time.time() - aggl_t0
aggl_score = smt.adjusted_rand_score(y_iris, aggl_pred)
print (" Sklearn AGGL score {}. Sklearn AGGL time {}".format(aggl_score, aggl_diff))
# Out:
#  Sklearn AGGL score 1.0. Sklearn AGGL time 0.0016300678253173828

# %%
# Здесь предскажем кластера, посчитаем метрику кластеризации и время работы, сравним со склерном
сustum_aggl = Clustering(metric='euclidean', n_clusters=2)
aggl_t0 = time.time()
aggl_pred = сustum_aggl.fit_predict(x_iris)
aggl_diff = time.time() - aggl_t0
aggl_score = smt.adjusted_rand_score(y_iris, aggl_pred)
print ("Our AGGL score {}. Our AGGL time {}".format(aggl_score, aggl_diff))
сustum_aggl.plot_dendrogram()
# Out:
# Our AGGL score 1.0. Our AGGL time 0.06721687316894531

# %% [markdown]
# # Боевое применение (3  балла)

# %% [markdown]
# Алгоритмы кластеризации прекрасны тем, что они позволяют быстро понять, как устроены наши данные. Давайте применим Ваш алгоритм для нашего конкурса!

# %% [markdown]
# Будем рассматривать каждую группу независимо от других групп. На каждой группе применим наш алгоритм и отрисуем денденограмму. По результатам кластерного анализа, Вам нужно ответить на следующие вопросы:
#
# 1) Можно ли по дендонаграмме (или по другим результатам кластеризации) сказать, где в группе аномалии? Каким образом?
#
# 2) Какое расстояние лучше использовать между заголовками страниц для кластеризации? Как еще учесть другую информацию о странице в расстоянии?
#
# 2) Какое качество f1_score Вы смогли получить на обучающем множестве методами кластеризации? (валидацию можете не делать, если таргет не используете)
#
# 4) Как можно результат кластеризации затем использовать для  финальной модели обучения с учителем?

# %% [markdown]
# Подсказка: самое важное - выбрать расстояние между заголовками. Самый простой вариант:  процент различных слов в двух заголовках. В семинаре мы рассматривали более сложный вариант, но Вы сможете придумать лучше.

# %%
doc_to_title = {}
with open('/Users/koteuka/Desktop/ML/Sphere/ML algorithms/kaggle_project/anomaly-detection-competition-ml1-ts-spring-2019/docs_titles.tsv') as f:
    for num_line, line in enumerate(f):
        if num_line == 0:
            continue
        data = line.strip().split('\t', 1)
        doc_id = int(data[0])
        if len(data) == 1:
            title = ''
        else:
            title = data[1]
        doc_to_title[doc_id] = title
print(len(doc_to_title))
# Out:
# 28026

# %%
train_data = pd.read_csv('/Users/koteuka/Desktop/ML/Sphere/ML algorithms/kaggle_project/anomaly-detection-competition-ml1-ts-spring-2019/train_groups.csv')
traingroups_titledata = {}
for i in range(len(train_data)):
    new_doc = train_data.iloc[i]
    doc_group = new_doc['group_id']
    doc_id = new_doc['doc_id']
    target = new_doc['target']
    title = doc_to_title[doc_id]
    if doc_group not in traingroups_titledata:
        traingroups_titledata[doc_group] = []
    traingroups_titledata[doc_group].append((doc_id, title, target))

# %% [markdown]
# Кластеризацию проводите в каждой группе отдельно, то есть изучайте, можно ли в группе  найти подкластер выбросов
#
# Документы можно представлять например словами из тайтла
#
# Главное подобрать хорошую функцию расстояния между документами
#
# Удачи! Все получится!

# %% [markdown]
# Замечание: в кластеризации можно использовать все данные, то есть трейн + тест, чтобы находить больше закономерностей

# %%
from sklearn.metrics import f1_score
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
y_all_pred = []
y_all = []

my_aggl=Clustering(n_clusters=2, metric='euclidean', linkage='average')

for j in range(1, 130):
    X_train = []
    y_train = []
    for i in range(len(traingroups_titledata[j])):
        X_train.append(traingroups_titledata[j][i][1])
        y_train.append(traingroups_titledata[j][i][2])
        y_all_pred.append(traingroups_titledata[j][i][2])
    
    X_train = TfidfVectorizer(ngram_range=(1,4)).fit_transform(X_train)
    X_train = X_train.toarray()
    y_pred = my_aggl.fit_predict(X_train)
    
    # инвертируем предсказанный вектор
    second = ((y_pred - np.ones(y_pred.shape[0], dtype='int')) * (-1))
    #print('group_id:', j, ' f1_score:', f1_score(y_train, second))
    for i in second:
        y_all.append(i)
    #print(y_pred, y_train)
    #my_aggl.plot_dendrogram()
    
print('f1_score: ', f1_score(y_all_pred, y_all))
# Out:
# f1_score:  0.45023956194387404

# %% [markdown]
# **Отрисуем случайные 10 групп и посмотрим**

# %%
y_all_pred = []
y_all = []

my_aggl=Clustering(n_clusters=2, metric='euclidean', linkage='average')
                   
for j in range(50, 60):
    X_train = []
    y_train = []
    for i in range(len(traingroups_titledata[j])):
        X_train.append(traingroups_titledata[j][i][1])
        y_train.append(traingroups_titledata[j][i][2])
        y_all_pred.append(traingroups_titledata[j][i][2])
        
    X_train = TfidfVectorizer(ngram_range=(1,4)).fit_transform(X_train)
    X_train = X_train.toarray()
    y_pred = my_aggl.fit_predict(X_train)
    
    second = ((y_pred - np.ones(y_pred.shape[0], dtype='int')) * (-1))
    #print('group_id:', j, ' f1_score:', f1_score(y_train, second))
    for i in second:
        y_all.append(i)
    #print(y_pred, y_train)
    my_aggl.plot_dendrogram()
print('f1_score: ', f1_score(y_all_pred, y_all))
# Out:
# f1_score:  0.40508628519527706

# %% [markdown]
# Ответы на вопросы:
#
# 1) Можно, необходимо просто заметить, какие объекты присоединялись с большим сдвигом "центра" кластера, то есть какие объекты находятся далеко от кластера.
#
# 2) Я использовал классическое tf-idf представление текстов.
#
# 2) ~0.45
#
# 4) Сделать ансамбль с методом классификации и выделять необходимый кластер путём голосования или просто удалять очевидные выбросы из группы.

# %% [markdown]
# Если получилось найти выбросы с помощью кластеризации, то не забывайте использовать его в финальном решении. Помните - использование различных подходов к решению задачи всегда улучшает финального качество.

# %% [markdown]
# # Контрольные вопросы
# Постарайтесь максимально развернуто и честно ответить на вопросы. Они охватывают тему алгоритмов кластеризации и скорее нужны преподавателям, чтобы понимать, что именно Вы усвоили плохо. Надеюсь, они подскажут, что именно в теме Вы не понимаете или наоборот порадают, что Вы все знаете ^_^

# %% [markdown]
# * Опишите, пожалуйста, для каких прикладных задач Вы бы стали использовать методы кластеризации?

# %% [markdown]
# Для классических задач выделения похожих объектов без учителя, например кластеризация групп по тематике или резюме по схожести работы

# %% [markdown]
# * Какие преимущества и недостатки Вы видите у следуюших алгоритмов кластеризации: kmeans, dbscan, агломеративная кластеризация?

# %% [markdown]
# kmeans требует задания количества кластеров, и зависит от начального задания центров. dbscan хорошо обрабатывает выбросы, но требует одинаковую плотность кластеров. Агломеративная кластеризация легко интерпретируема, но требует больших затрат памяти на хранение матрицы расстояний.

# %% [markdown]
# * На лекции было показано, что EM алгоритм находит оценку максимального правдоподобия в задаче со сккрытыми переменными. Из курса мат. статистики Вы можете знать, оценка максимального правдоподобия "оптимальная" во многих смыслах. В каких же случаях тогда не следует применять метод максимального правдоподобия?

# %% [markdown]
# ***Ваше ответ здесь***

# %% [markdown]
# * Представьте, что у Вас есть набор текстовых документов, и Вы хотите разбить эти документы на тематики - новости, спорт, кулинария, кино и так далее. Размеченной выборки у Вас нет, только сами тексты документов. Какие алгоритмы и какие признаки Вы бы использовали для решения данной задачи?

# %% [markdown]
# ***Ваше ответ здесь***

# %% [markdown]
# * Теперь представьте, что небольшая часть Ваших текстов была размечена людьми, но большая часть так и осталась без таргета. Смогли ли бы Вы использовать эти данные для улучения качества кластеризации? (эта задача называется semi-supervised learning)

# %% [markdown]
# ***Ваше ответ здесь***

# %% [markdown]
# Здесь Вы можете оставить отзыв о этой домашней работе или о всем курсе.

# %% [markdown]
# *** ВАШ ОТЗЫВ ЗДЕСЬ***
# Всё супер, продолжайте в том же духе!
